# %%
from PIL import Image
import os, glob, numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, Activation
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger

# %%
data_dir = "fire_dataset"
categories = ["fire", "non_fire", "non2_fire"]
num_classes = len(categories)

# %%
# 이미지의 크기
image_w = 128
image_h = 128

# %%
# 펼치기 
pixels = image_h * image_w * 3

# %%
X = []
y = []

# %%
for idx, category in enumerate(categories):
    
    #one-hot 돌리기.
    label = [0 for i in range(num_classes)]
    label[idx] = 1
 
    image_dir = data_dir + "/" + category
    files = glob.glob(image_dir+"/*.png")
    print(category, " 파일 길이 : ", len(files))
    for i, f in enumerate(files):
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))
        data = np.asarray(img)
 
        X.append(data)
        y.append(label)
 
        if i % 700 == 0:
            print(category, " : ", f)
# Out:
# fire  파일 길이 :  1430
# fire  :  fire_dataset/fire\fire.1.png
# fire  :  fire_dataset/fire\fire.309.png
# fire  :  fire_dataset/fire\fire.964.png
# non_fire  파일 길이 :  576
# non_fire  :  fire_dataset/non_fire\non_fire.1.png
# non2_fire  파일 길이 :  294
# non2_fire  :  fire_dataset/non2_fire\non_fire.255.png

# %%
X = np.array(X)
y = np.array(y)
#1 0  이면 man
#0 1  이면 woman

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
xy = (X_train, X_test, y_train, y_test)
np.save("npy/fire_data.npy", xy)
print("ok", len(y))
# Out:
# ok 2300
# C:\Users\jangj\anaconda3\lib\site-packages\numpy\lib\npyio.py:528: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %%
X_train, X_test, y_train, y_test = np.load('npy/fire_data.npy', allow_pickle = True)

# %%
categories = ["fire", "non_fire", "non2_fire"]
num_classes = len(categories)

#일반화
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# %%
model = Sequential()
model.add(Conv2D(64, 3, strides= 1, padding='same', input_shape=X_train.shape[1:]))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(Conv2D(64, 3, strides= 1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(MaxPool2D((2,2), strides=2))

model.add(Conv2D(128, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(Conv2D(128, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(MaxPool2D((2, 2), strides=2))

model.add(Conv2D(256, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(Conv2D(256, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(Conv2D(256, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(MaxPool2D((2, 2), strides=2))

model.add(Conv2D(512, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(Conv2D(512, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(Conv2D(512, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(MaxPool2D((2, 2), strides=2))
model.add(MaxPool2D((2, 2), strides=2))

model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 128, 128, 64)      1792
#
#  batch_normalization_40 (Bat  (None, 128, 128, 64)     256
#  chNormalization)
#
#  activation_40 (Activation)  (None, 128, 128, 64)      0
#
#  conv2d_41 (Conv2D)          (None, 128, 128, 64)      36928
#
#  batch_normalization_41 (Bat  (None, 128, 128, 64)     256
#  chNormalization)
#
#  activation_41 (Activation)  (None, 128, 128, 64)      0
#
#  max_pooling2d_20 (MaxPoolin  (None, 64, 64, 64)       0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 128)       73856
#
#  batch_normalization_42 (Bat  (None, 64, 64, 128)      512
#  chNormalization)
#
#  activation_42 (Activation)  (None, 64, 64, 128)       0
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 128)       147584
#
#  batch_normalization_43 (Bat  (None, 64, 64, 128)      512
#  chNormalization)
#
#  activation_43 (Activation)  (None, 64, 64, 128)       0
#
#  max_pooling2d_21 (MaxPoolin  (None, 32, 32, 128)      0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 32, 32, 256)       295168
#
#  batch_normalization_44 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  activation_44 (Activation)  (None, 32, 32, 256)       0
#
#  conv2d_45 (Conv2D)          (None, 32, 32, 256)       590080
#
#  batch_normalization_45 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  activation_45 (Activation)  (None, 32, 32, 256)       0
#
#  conv2d_46 (Conv2D)          (None, 32, 32, 256)       590080
#
#  batch_normalization_46 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  activation_46 (Activation)  (None, 32, 32, 256)       0
#
#  max_pooling2d_22 (MaxPoolin  (None, 16, 16, 256)      0
#  g2D)
#
#  conv2d_47 (Conv2D)          (None, 16, 16, 512)       1180160
#
#  batch_normalization_47 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  activation_47 (Activation)  (None, 16, 16, 512)       0
#
#  conv2d_48 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  batch_normalization_48 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  activation_48 (Activation)  (None, 16, 16, 512)       0
#
#  conv2d_49 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  batch_normalization_49 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  activation_49 (Activation)  (None, 16, 16, 512)       0
#
#  max_pooling2d_23 (MaxPoolin  (None, 8, 8, 512)        0
#  g2D)
#
#  max_pooling2d_24 (MaxPoolin  (None, 4, 4, 512)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 8192)              0
#
#  dense_12 (Dense)            (None, 4096)              33558528
#
#  dropout_8 (Dropout)         (None, 4096)              0
#
#  dense_13 (Dense)            (None, 4096)              16781312
#
#  dropout_9 (Dropout)         (None, 4096)              0
#
#  dense_14 (Dense)            (None, 3)                 12291
#
# =================================================================
# Total params: 57,998,147
# Trainable params: 57,992,771
# Non-trainable params: 5,376
# _________________________________________________________________

# %%
mcp = ModelCheckpoint('save/best-fire-model.h5',save_best_only=True)

# %%
mes = EarlyStopping(patience=20)

# %%
rlr = ReduceLROnPlateau(factor=0.1, patience=5)

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(0.0005),
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, 
                    batch_size = 64, 
                    epochs = 200, 
                    verbose = 1,
                    validation_data=(X_test, y_test),
                    callbacks = [mcp, mes, rlr])
# Out:
# Epoch 1/200
# 27/27 [==============================] - 6s 208ms/step - loss: 6.3922 - accuracy: 0.5397 - val_loss: 0.9627 - val_accuracy: 0.6174 - lr: 5.0000e-04
# Epoch 2/200
# 27/27 [==============================] - 4s 160ms/step - loss: 1.0091 - accuracy: 0.6041 - val_loss: 1.0396 - val_accuracy: 0.2522 - lr: 5.0000e-04
# Epoch 3/200
# 27/27 [==============================] - 5s 188ms/step - loss: 0.9626 - accuracy: 0.5913 - val_loss: 0.9572 - val_accuracy: 0.6174 - lr: 5.0000e-04
# Epoch 4/200
# 27/27 [==============================] - 5s 188ms/step - loss: 0.9045 - accuracy: 0.6017 - val_loss: 0.9373 - val_accuracy: 0.6174 - lr: 5.0000e-04
# Epoch 5/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.9160 - accuracy: 0.6075 - val_loss: 0.9569 - val_accuracy: 0.6174 - lr: 5.0000e-04
# Epoch 6/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.8941 - accuracy: 0.6035 - val_loss: 0.9559 - val_accuracy: 0.6174 - lr: 5.0000e-04
# Epoch 7/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.8679 - accuracy: 0.6162 - val_loss: 1.0088 - val_accuracy: 0.6174 - lr: 5.0000e-04
# Epoch 8/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.7957 - accuracy: 0.6226 - val_loss: 0.9696 - val_accuracy: 0.6174 - lr: 5.0000e-04
# Epoch 9/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.7710 - accuracy: 0.6272 - val_loss: 0.9900 - val_accuracy: 0.6174 - lr: 5.0000e-04
# Epoch 10/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.6528 - accuracy: 0.6614 - val_loss: 0.7777 - val_accuracy: 0.6922 - lr: 5.0000e-07
# Epoch 30/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.6749 - accuracy: 0.6736 - val_loss: 0.7800 - val_accuracy: 0.6922 - lr: 5.0000e-08
# Epoch 31/200
# 27/27 [==============================] - 5s 169ms/step - loss: 0.6584 - accuracy: 0.6806 - val_loss: 0.7811 - val_accuracy: 0.6904 - lr: 5.0000e-08
# Epoch 32/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.6643 - accuracy: 0.6742 - val_loss: 0.7823 - val_accuracy: 0.6904 - lr: 5.0000e-08
# Epoch 33/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.6570 - accuracy: 0.6899 - val_loss: 0.7832 - val_accuracy: 0.6904 - lr: 5.0000e-08
# Epoch 34/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.6510 - accuracy: 0.6829 - val_loss: 0.7837 - val_accuracy: 0.6887 - lr: 5.0000e-08
# Epoch 35/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6553 - accuracy: 0.6800 - val_loss: 0.7844 - val_accuracy: 0.6887 - lr: 5.0000e-09
# Epoch 36/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.6517 - accuracy: 0.6858 - val_loss: 0.7846 - val_accuracy: 0.6887 - lr: 5.0000e-09
# Epoch 37/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.6508 - accuracy: 0.6812 - val_loss: 0.7849 - val_accuracy: 0.6887 - lr: 5.0000e-09
# Epoch 38/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6645 - accuracy: 0.6696 - val_loss: 0.7851 - val_accuracy: 0.6887 - lr: 5.0000e-09
# Epoch 39/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.6599 - accuracy: 0.6910 - val_loss: 0.7857 - val_accuracy: 0.6887 - lr: 5.0000e-09

# %%
model.save_weights('save/model-fire-weights.h5')

# %%
model.save('save/model-fire-whole.h5')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['epoch', 'validation'], loc = 'upper left')
plt.show()

# %%
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))

plt.plot(x_len, y_vloss, marker='.', c='red', label='val_set_loss')
plt.plot(x_len, y_loss, marker='.', c='blue', label='train_set_oss')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()
plt.show()

# %%
# predict 메서드로 테스트 세트에 대한 예측 결과 확인

CLASSES = np.array(['fire', 'non_fire', 'non2_fire'])

preds = model.predict(X_test, batch_size=64, verbose=1) 
preds_single = CLASSES[np.argmax(preds, axis = -1)]
actual_single = CLASSES[np.argmax(y_test, axis = -1)]
# Out:
# 9/9 [==============================] - 0s 43ms/step

# %%
model.evaluate(X_test, y_test)
# Out:
# 18/18 [==============================] - 0s 23ms/step - loss: 0.7857 - accuracy: 0.6887
# [0.7856830954551697, 0.6886956691741943]

# %%
n_to_show = 10
indices = np.random.choice(range(len(X_test)), n_to_show)

fig = plt.figure(figsize = (15, 3))
fig.subplots_adjust(hspace = 0.4, wspace = 0.4)

for i, idx in enumerate(indices):
    img = X_test[idx] 
    ax = fig.add_subplot(1, n_to_show, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, 'pred = ' + str(preds_single[idx]), fontsize = 10, ha = 'center', transform = ax.transAxes)
    ax.text(0.5, -0.7, 'act = ' + str(actual_single[idx]), fontsize = 10, ha = 'center', transform = ax.transAxes)
    ax.imshow(img)
